# %% [markdown]
# # ROGII Submission Pipeline
#
# This notebook is a Kaggle submission scaffold: point it at the repo scripts or prebuilt artifacts, then write `submission.csv`.

# %%
from pathlib import Path
import sys

ROOT = Path('/kaggle/working')
if (ROOT / 'scripts').exists():
    sys.path.append(str(ROOT / 'scripts'))

print(ROOT)

# %% [markdown]
# Run the Kaggle-side submission chain with the checked-in scripts or prebuilt artifacts:
# 1. load data and sample submission
# 2. resolve baseline / blend inputs
# 3. apply postprocess
# 4. validate row order and schema
# 5. write `submission.csv`
