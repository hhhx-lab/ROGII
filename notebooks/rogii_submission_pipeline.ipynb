# %% [markdown]
# # ROGII Submission Pipeline
#
# This notebook mirrors the local submission flow: load data, build baseline, blend validated models, postprocess, and write `submission.csv`.

# %%
from pathlib import Path
import sys

ROOT = Path('/kaggle/working')
if (ROOT / 'scripts').exists():
    sys.path.append(str(ROOT / 'scripts'))

print(ROOT)

# %% [markdown]
# Run the local scripts in Kaggle order:
# 1. baseline feature build
# 2. geometry / Part 3 feature build
# 3. blend validated predictions
# 4. postprocess
# 5. make final submission
